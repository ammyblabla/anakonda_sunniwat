# %%
import tweepy
import json

consumer_key = 'Z0SBNRfeu2ILIGPkh92XYOjlG'
consumer_secret = 'eutGcIHzvi9KuFTnBDs4k6NsmoMQRfBYtmXPjm5IvW64Ziqyu1'
access_token = '145576185-KgDQBGa7dnawsSFH2BbQvC0wjUnKmHwQhSOFsUPm'
access_secret = 'Eu58gEjGmQAmMv0A6tDpfRs8gpVDarhr1lTurmaKgyq5H'

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_secret)

# Creating the API object while passing in auth information
api = tweepy.API(auth)

# %%
screen_name = 'ammyblabla'
user = api.get_user(screen_name)

# %%
print(type(user), user)
# Out:
# <class 'tweepy.models.User'> User(_api=<tweepy.api.API object at 0x0000013318DC7FD0>, _json={'id': 145576185, 'id_str': '145576185', 'name': 'แอมศรีมณีศักดิ์', 'screen_name': 'AmmyBlabla', 'location': '', 'profile_location': None, 'description': 'SS59 | KU75 CPE29 | PD101 STAN | RETWEETER', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': True, 'followers_count': 44, 'friends_count': 374, 'listed_count': 0, 'created_at': 'Wed May 19 09:14:08 +0000 2010', 'favourites_count': 53, 'utc_offset': 25200, 'time_zone': 'Bangkok', 'geo_enabled': True, 'verified': False, 'statuses_count': 40993, 'lang': 'en', 'status': {'created_at': 'Sun Mar 25 13:17:23 +0000 2018', 'id': 977897233554202626, 'id_str': '977897233554202626', 'text': 'RT @zeantoeiza: เดี๋ยวๆ 5555555555555555555555555555555555555 https://t.co/gmVzjkcoE8', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'zeantoeiza', 'name': 'น้องหนัม v.2', 'id': 943142294932164609, 'id_str': '943142294932164609', 'indices': [3, 14]}], 'urls': [], 'media': [{'id': 977420198771748864, 'id_str': '977420198771748864', 'indices': [62, 85], 'media_url': 'http://pbs.twimg.com/media/DZB-fgAU8AAyCRJ.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DZB-fgAU8AAyCRJ.jpg', 'url': 'https://t.co/gmVzjkcoE8', 'display_url': 'pic.twitter.com/gmVzjkcoE8', 'expanded_url': 'https://twitter.com/zeantoeiza/status/977420258234458112/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 665, 'h': 680, 'resize': 'fit'}, 'large': {'w': 2004, 'h': 2048, 'resize': 'fit'}, 'medium': {'w': 1174, 'h': 1200, 'resize': 'fit'}}, 'source_status_id': 977420258234458112, 'source_status_id_str': '977420258234458112', 'source_user_id': 943142294932164609, 'source_user_id_str': '943142294932164609'}]}, 'extended_entities': {'media': [{'id': 977420198771748864, 'id_str': '977420198771748864', 'indices': [62, 85], 'media_url': 'http://pbs.twimg.com/media/DZB-fgAU8AAyCRJ.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DZB-fgAU8AAyCRJ.jpg', 'url': 'https://t.co/gmVzjkcoE8', 'display_url': 'pic.twitter.com/gmVzjkcoE8', 'expanded_url': 'https://twitter.com/zeantoeiza/status/977420258234458112/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 665, 'h': 680, 'resize': 'fit'}, 'large': {'w': 2004, 'h': 2048, 'resize': 'fit'}, 'medium': {'w': 1174, 'h': 1200, 'resize': 'fit'}}, 'source_status_id': 977420258234458112, 'source_status_id_str': '977420258234458112', 'source_user_id': 943142294932164609, 'source_user_id_str': '943142294932164609'}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Mar 24 05:42:03 +0000 2018', 'id': 977420258234458112, 'id_str': '977420258234458112', 'text': 'เดี๋ยวๆ 5555555555555555555555555555555555555 https://t.co/gmVzjkcoE8', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 977420198771748864, 'id_str': '977420198771748864', 'indices': [46, 69], 'media_url': 'http://pbs.twimg.com/media/DZB-fgAU8AAyCRJ.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DZB-fgAU8AAyCRJ.jpg', 'url': 'https://t.co/gmVzjkcoE8', 'display_url': 'pic.twitter.com/gmVzjkcoE8', 'expanded_url': 'https://twitter.com/zeantoeiza/status/977420258234458112/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 665, 'h': 680, 'resize': 'fit'}, 'large': {'w': 2004, 'h': 2048, 'resize': 'fit'}, 'medium': {'w': 1174, 'h': 1200, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 977420198771748864, 'id_str': '977420198771748864', 'indices': [46, 69], ...

# %%
dict(user)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-7dbaed680a49> in <module>()
# ----> 1 dict(user)
#
# TypeError: 'User' object is not iterable
