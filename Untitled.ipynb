# %%
import tweepy

# %%
import sys
import tweepy
import time
from random import randint

CONSUMER_KEY = 'Z0SBNRfeu2ILIGPkh92XYOjlG'
CONSUMER_SECRET = 'eutGcIHzvi9KuFTnBDs4k6NsmoMQRfBYtmXPjm5IvW64Ziqyu1'
ACCESS_TOKEN = '145576185-KgDQBGa7dnawsSFH2BbQvC0wjUnKmHwQhSOFsUPm'
ACCESS_TOKEN_SECRET = 'Eu58gEjGmQAmMv0A6tDpfRs8gpVDarhr1lTurmaKgyq5H' 

try:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
    api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, compression=True)
    c = tweepy.Cursor(api.followers_ids, id = 'McDonalds')
    print ("type(c)=", type(c))
    ids = []
    for page in c.pages():
        ids.append(page)
    print ("ids=", ids)
    print ("ids[0]=", ids[0])
    print ("len(ids[0])=", len(ids[0]))
    print (5/0)

except tweepy.TweepError:
    print ("tweepy.TweepError=")#, tweepy.TweepError
except:
    e = sys.exc_info()[0]
    print ("Error: %s" % e)
    #print "error."

# %%
CONSUMER_KEY = 'Z0SBNRfeu2ILIGPkh92XYOjlG'
CONSUMER_SECRET = 'eutGcIHzvi9KuFTnBDs4k6NsmoMQRfBYtmXPjm5IvW64Ziqyu1'
ACCESS_TOKEN = '145576185-KgDQBGa7dnawsSFH2BbQvC0wjUnKmHwQhSOFsUPm'
ACCESS_TOKEN_SECRET = 'Eu58gEjGmQAmMv0A6tDpfRs8gpVDarhr1lTurmaKgyq5H'
key = ['s0YmRKw8u3AHEiv0EHkGWz3Cr','AUQEbdCDfVn7YSvGtscmX9ZKjIWP3wTEQ02k5D8hJcKLvXP9yL','3220159244-6sKt4mtmC9d9lxm3ZQUBh2OJgDG7dyQrWjdgtbv','NXfKBrTWi8wyxPEIrmISmsmwCqIHjvBkYHuQKz3PUCu69']
CONSUMER_KEY = key[0]
CONSUMER_SECRET = key[1]
ACCESS_TOKEN = key[2]
ACCESS_TOKEN_SECRET = key[3]
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, compression=True, parser=tweepy.parsers.JSONParser())

# %%
def get_followers(screen_name):
    api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, compression=True)
    users = []
    page_count = 0
    for i, user in enumerate(tweepy.Cursor(api.followers, screen_name=screen_name, count=20).pages()):
        print(f'Getting page {i} for followers')
        print(user)
        print(type(user))
        users += user
    return users

# %%
screen_name = 'Pada_Sweat16'
cursor1 = tweepy.Cursor(api.followers, screen_name=screen_name, count=300).pages()
for i, user in enumerate(tweepy.Cursor(api.followers, screen_name=screen_name, count=20).pages()):
    print(f'Getting page {i} for followers')
    print(user)
    print(type(user))

cursor1.next()
for i, user in enumerate(tweepy.Cursor(api.followers, screen_name=screen_name, count=20).pages()):
    print(f'Getting page {i} for followers')
    print(user)
    print(type(user))
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-19-366571a7c31a> in <module>()
#       1 screen_name = 'Pada_Sweat16'
#       2 cursor1 = tweepy.Cursor(api.followers, screen_name=screen_name, count=300).pages()
# ----> 3 for i, user in enumerate(tweepy.Cursor(api.followers, screen_name=screen_name, count=20).pages()):
#       4     print(f'Getting page {i} for followers')
#       5     print(user)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#      73         data, cursors = self.method(cursor=self.next_cursor,
#      74                                     *self.args,
# ...

# %%
check_limit
# Out:
# [User(_api=<tweepy.api.API object at 0x000001D1DECE3E48>, _json={'id': 89446706, 'id_str': '89446706', 'name': 'แมวไบค์.cpp', 'screen_name': 'ds41744', 'location': '46610 Bésixdouze Star', 'description': "@CoffeeOum's bro | นักร่วมแต่งเพลง #วงเล็บปีกกาอ๊าอิยาอิยาก็พอโว๊ะโอเย", 'url': 'https://t.co/xMnqYutVFv', 'entities': {'url': {'urls': [{'url': 'https://t.co/xMnqYutVFv', 'expanded_url': 'https://twitter.com/ds41744', 'display_url': 'twitter.com/ds41744', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 2146, 'friends_count': 387, 'listed_count': 76, 'created_at': 'Thu Nov 12 13:34:46 +0000 2009', 'favourites_count': 8283, 'utc_offset': 25200, 'time_zone': 'Bangkok', 'geo_enabled': True, 'verified': False, 'statuses_count': 333502, 'lang': 'th', 'status': {'created_at': 'Tue Apr 24 13:32:37 +0000 2018', 'id': 988772701329281024, 'id_str': '988772701329281024', 'text': 'ทำไม title ของ smtmth มันเหมือน smtm6 เลยหว่า 55555', 'truncated': Fals
# ...

# %%
x = 1

# %%
def foo(x):
    global x
    x = 2
# Out:
#   File "<ipython-input-21-d1a5a4631ad4>", line 2
#     global x
#     ^
# SyntaxError: name 'x' is parameter and global

# %%
import json

# %%
def open_json_file(filename):
    lines = []
    with open(filename) as f:
        lines = f.readlines()
    f.close()
    data = []
    for line in lines:
        temp= json.loads(line)
        data.append(temp)
    return data

# %%
filename = 'sweat16_Pada_Sweat16_followers.json'

# %%
x  = open_json_file(filename)

# %%
type(x[0])
# Out:
# dict
